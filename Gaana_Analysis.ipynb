# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 📘 Overview
# The **Songs Dataset** contains metadata of **41,355 songs**, including information about song titles, artists, durations, and languages. It serves as a useful resource for music analysis, recommendation systems, and multilingual content insights.
#
# ---
#
# ## 📊 Dataset Summary
#
# | Feature | Description | Data Type | Example | Unique Values |
# |----------|--------------|------------|-----------|----------------|
# | **name** | Title of the song | `object` | `Dil - E - Nadan Tujhe` | 31,534 |
# | **singer** | Name(s) of the singer(s), sometimes multiple separated by `|` | `object` | `Chitra Singh | Jagjit Singh` | 6,196 |
# | **singer_id** | Unique artist identifier(s) corresponding to the singers | `object` | `/artist/jagjeet-singh-1` | 6,580 |
# | **duration** | Duration of the song in `mm:ss` format | `object` | `05:00` | 1,309 |
# | **link** | URL path or identifier to access the song details | `object` | `/dil-e-nadan-tujhe-3` | 36,361 |
# | **language** | Language of the song | `object` | `Urdu`, `Telugu`, `Hindi`, etc. | 16 |
#
# ---
#
# ## 📈 Key Insights
# - The dataset includes **songs in 16 different languages**, with **Telugu** being the most frequent (~5,000 entries).
# - The most represented singer is **Lata Mangeshkar** with **1,410 songs**.
# - The most common song duration is around **3 minutes (03:02)**.
# - There are **31,534 unique song names**, showing significant diversity in the collection.
#
# ---
#
# ## 📦 Possible Use Cases
# - 🎧 **Music Recommendation Systems** — based on singers, duration, or language.
# - 🧠 **Language-based Music Analysis** — studying song trends across regions.
# - 🔍 **Data Cleaning & Parsing Tasks** — handling multi-singer or multi-language metadata.
# - 📈 **Exploratory Data Analysis (EDA)** — visualizing duration distributions and singer popularity.
#
# ---
# """

# %% [markdown]
# # 1) Overall Data Analytics

# %% [markdown]
# 1.1) Importing the necessary Liabraries 🧰

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# 1.2) Loading the dataset - Gaana Dataset 📂

# %%
# !git clone 'https://github.com/HarshvardhanSingh-13/Datasets'
# Out:
# Cloning into 'Datasets'...
# remote: Enumerating objects: 347, done.
# remote: Counting objects: 100% (105/105), done.
# remote: Compressing objects: 100% (90/90), done.
# remote: Total 347 (delta 25), reused 0 (delta 0), pack-reused 242 (from 1)
# Receiving objects: 100% (347/347), 302.89 MiB | 19.38 MiB/s, done.
# Resolving deltas: 100% (139/139), done.
# Updating files: 100% (245/245), done.

# %%
df = pd.read_csv('/content/Datasets/Gaana/songs.csv')

# %% [markdown]
# 1.3) Viewing the data using info() and describe() 🧾

# %%
df.head()
# Out:
#                                       name                     singer  \
# 0                    Dil - E - Nadan Tujhe  Chitra Singh|Jagjit Singh
# 1        Agar Hum Kahen Aur Woh Muskara De  Chitra Singh|Jagjit Singh
# 2                            Unke Dekhe Se               Jagjit Singh
# 3  Yeh Na Thi Hamari Qismat - Chitra Singh               Chitra Singh
# 4                  Hazaron Khwahishen Aisi               Jagjit Singh
#
#                                       singer_id duration  \
# 0  /artist/chitra-singh|/artist/jagjeet-singh-1    05:00
# 1  /artist/chitra-singh|/artist/jagjeet-singh-1    06:26
# 2                       /artist/jagjeet-singh-1    03:41
# 3                          /artist/chitra-singh    04:26
# 4                       /artist/jagjeet-singh-1    05:39
#
#                                   link language
# 0                 /dil-e-nadan-tujhe-3     Urdu
# 1  /agar-hum-kahen-aur-woh-muskura-den     Urdu
# 2                       /unke-dekhe-se     Urdu
# ...

# %%
df.tail()
# Out:
#                                                     name  \
# 41350  Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 41351                                Ei Ki Go Shesh Daan
# 41352                                       Ei Je Bangla
# 41353                               Jatone Hridaye Rekho
# 41354                            Tomar Je Oi Haater Mala
#
#                                singer  \
# 41350                   Kishore Kumar
# 41351                    Feroza Begum
# 41352  Sandhya Mukherjee|Hemant Kumar
# 41353                Ajoy Chakrabarty
# 41354                     Asha Bhosle
#
#                                                singer_id duration  \
# 41350                              /artist/kishore-kumar    03:23
# 41351                               /artist/feroza-begum    03:56
# 41352  /artist/sandhya-mukherjee|/artist/hemanta-mukh...    07:36
# 41353                           /artist/ajoy-chakrabarty    04:29
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41355 entries, 0 to 41354
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       41355 non-null  object
#  1   singer     41355 non-null  object
#  2   singer_id  41355 non-null  object
#  3   duration   41355 non-null  object
#  4   link       41355 non-null  object
#  5   language   41355 non-null  object
# dtypes: object(6)
# memory usage: 1.9+ MB

# %%
df.describe()
# Out:
#                        name           singer                singer_id  \
# count                 41355            41355                    41355
# unique                31534             6196                     6580
# top     O Mere Dil Ke Chain  Lata Mangeshkar  /artist/lata-mangeshkar
# freq                     26             1410                     1410
#
#        duration                       link language
# count     41355                      41355    41355
# unique     1309                      36361       16
# top       03:02  /ek-baar-zara-phir-keh-do   Telugu
# freq        447                          2     4996

# %% [markdown]
# 1.4) Checking duplicate entries 🧩🧩

# %%
df[df['link'] == 	"/ek-baar-zara-phir-keh-do"]
# Out:
#                            name                        singer  \
# 21388  Ek Baar Zara Phir Keh Do  Hemant Kumar|Lata Mangeshkar
# 26381  Ek Baar Zara Phir Keh Do  Hemant Kumar|Lata Mangeshkar
#
#                                                singer_id duration  \
# 21388  /artist/hemanta-mukherjee|/artist/lata-mangeshkar    04:08
# 26381  /artist/hemanta-mukherjee|/artist/lata-mangeshkar    04:08
#
#                             link language
# 21388  /ek-baar-zara-phir-keh-do    Hindi
# 26381  /ek-baar-zara-phir-keh-do      Old

# %%
df[df['name'] == "O Mere Dil Ke Chain"]
# Out:
#                       name         singer              singer_id duration  \
# 18066  O Mere Dil Ke Chain  Kishore Kumar  /artist/kishore-kumar    04:34
# 19022  O Mere Dil Ke Chain  Kishore Kumar  /artist/kishore-kumar    04:36
# 19322  O Mere Dil Ke Chain  Kishore Kumar  /artist/kishore-kumar    04:36
# 19676  O Mere Dil Ke Chain  Kishore Kumar  /artist/kishore-kumar    04:36
# 20087  O Mere Dil Ke Chain  Kishore Kumar  /artist/kishore-kumar    04:36
# 21423  O Mere Dil Ke Chain  Kishore Kumar  /artist/kishore-kumar    04:36
# 21510  O Mere Dil Ke Chain  Kishore Kumar  /artist/kishore-kumar    04:36
# 21771  O Mere Dil Ke Chain  Kishore Kumar  /artist/kishore-kumar    04:36
# 21883  O Mere Dil Ke Chain  Kishore Kumar  /artist/kishore-kumar    04:36
# 22471  O Mere Dil Ke Chain  Kishore Kumar  /artist/kishore-kumar    04:36
# 22535  O Mere Dil Ke Chain  Kishore Kumar  /artist/kishore-kumar    04:36
# 22756  O Mere Dil Ke Chain  Kishore Kumar  /artist/kishore-kumar    04:36
# ...

# %%
df['link'].nunique()
# Out:
# 36361

# %% [markdown]
# 1.5) Checking Null Values )🔍🚫

# %%
df.isnull().sum()
# Out:
# name         0
# singer       0
# singer_id    0
# duration     0
# link         0
# language     0
# dtype: int64

# %% [markdown]
# 1.6) Removing Duplicate Enteries 🧹

# %%
df.drop_duplicates(subset = ['link'], inplace=True)

# %%
df
# Out:
#                                                     name  \
# 0                                  Dil - E - Nadan Tujhe
# 1                      Agar Hum Kahen Aur Woh Muskara De
# 2                                          Unke Dekhe Se
# 3                Yeh Na Thi Hamari Qismat - Chitra Singh
# 4                                Hazaron Khwahishen Aisi
# ...                                                  ...
# 41350  Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 41351                                Ei Ki Go Shesh Daan
# 41352                                       Ei Je Bangla
# 41353                               Jatone Hridaye Rekho
# 41354                            Tomar Je Oi Haater Mala
#
#                                singer  \
# 0           Chitra Singh|Jagjit Singh
# 1           Chitra Singh|Jagjit Singh
# 2                        Jagjit Singh
# 3                        Chitra Singh
# 4                        Jagjit Singh
# ...                               ...
# ...

# %%
df.describe()
# Out:
#             name                  singer                      singer_id  \
# count      36361                   36361                          36361
# unique     31534                    6196                           6580
# top     Padhyams  S. P. Balasubrahmanyam  /artist/s-p-balasubrahamanyam
# freq          20                    1151                           1155
#
#        duration                      link language
# count     36361                     36361    36361
# unique     1309                     36361       15
# top       03:02  /tomar-je-oi-haater-mala   Telugu
# freq        417                         1     4995

# %%
df[df['name'] == 'O Mere Dil Ke Chain']
# Out:
#                       name         singer              singer_id duration  \
# 18066  O Mere Dil Ke Chain  Kishore Kumar  /artist/kishore-kumar    04:34
# 19022  O Mere Dil Ke Chain  Kishore Kumar  /artist/kishore-kumar    04:36
# 19322  O Mere Dil Ke Chain  Kishore Kumar  /artist/kishore-kumar    04:36
# 19676  O Mere Dil Ke Chain  Kishore Kumar  /artist/kishore-kumar    04:36
# 20087  O Mere Dil Ke Chain  Kishore Kumar  /artist/kishore-kumar    04:36
# 21423  O Mere Dil Ke Chain  Kishore Kumar  /artist/kishore-kumar    04:36
# 21510  O Mere Dil Ke Chain  Kishore Kumar  /artist/kishore-kumar    04:36
# 21771  O Mere Dil Ke Chain  Kishore Kumar  /artist/kishore-kumar    04:36
# 21883  O Mere Dil Ke Chain  Kishore Kumar  /artist/kishore-kumar    04:36
# 22471  O Mere Dil Ke Chain  Kishore Kumar  /artist/kishore-kumar    04:36
# 22535  O Mere Dil Ke Chain  Kishore Kumar  /artist/kishore-kumar    04:36
# 22756  O Mere Dil Ke Chain  Kishore Kumar  /artist/kishore-kumar    04:36
# ...

# %%
df.drop_duplicates(subset=['name','singer','singer_id','duration'], inplace=True)

# %%
df.describe()
# Out:
#             name       singer            singer_id duration  \
# count      32949        32949                32949    32949
# unique     31534         6196                 6580     1309
# top     Padhyams  P. Susheela  /artist/p-suseela-2    04:00
# freq          19          938                  938      377
#
#                             link language
# count                      32949    32949
# unique                     32949       15
# top     /tomar-je-oi-haater-mala   Telugu
# freq                           1     4635

# %% [markdown]
# 2) Column wise Exploration 📊🔍

# %% [markdown]
# 2.1) "name" Column Exploration and Cleaning 🔍🧹

# %%
df['name']
# Out:
# 0                                    Dil - E - Nadan Tujhe
# 1                        Agar Hum Kahen Aur Woh Muskara De
# 2                                            Unke Dekhe Se
# 3                  Yeh Na Thi Hamari Qismat - Chitra Singh
# 4                                  Hazaron Khwahishen Aisi
#                                ...
# 41350    Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 41351                                  Ei Ki Go Shesh Daan
# 41352                                         Ei Je Bangla
# 41353                                 Jatone Hridaye Rekho
# 41354                              Tomar Je Oi Haater Mala
# Name: name, Length: 41355, dtype: object

# %%
df['name'].unique()
# Out:
# array(['Dil - E - Nadan Tujhe', 'Agar Hum Kahen Aur Woh Muskara De',
#        'Unke Dekhe Se', ..., 'Ei Je Bangla', 'Jatone Hridaye Rekho',
#        'Tomar Je Oi Haater Mala'], dtype=object)

# %%
df['name'].nunique()
# Out:
# 31534

# %%
df['name'].value_counts()
# Out:
# name
# O Mere Dil Ke Chain               26
# Hamen Tumse Pyar Kitna            22
# Padhyams                          20
# Yeh Sham Mastani                  18
# Chura Liya Hai Tumne Jo Dil Ko    18
#                                   ..
# Neere Neenu Baare                  1
# B/A, M/A/ Degree Iddaru            1
# Mannalli Arali                     1
# Kaanada Devaru (Male)              1
# Hari Govinda                       1
# Name: count, Length: 31534, dtype: int64

# %%
df[df['name'] == 'Tuma Gaan Mahu Machhi']
# Out:
#                         name                  singer  \
# 38476  Tuma Gaan Mahu Machhi  Pranab Kishore Patnaik
# 38631  Tuma Gaan Mahu Machhi  Pranab Kishore Patnaik
# 38639  Tuma Gaan Mahu Machhi  Pranab Kishore Patnaik
# 38706  Tuma Gaan Mahu Machhi  Pranab Kishore Patnaik
# 38717  Tuma Gaan Mahu Machhi  Pranab Kishore Patnaik
# 38738  Tuma Gaan Mahu Machhi  Pranab Kishore Patnaik
# 38765  Tuma Gaan Mahu Machhi  Pranab Kishore Patnaik
# 38768  Tuma Gaan Mahu Machhi  Pranab Kishore Patnaik
# 38788  Tuma Gaan Mahu Machhi  Pranab Kishore Patnaik
# 38808  Tuma Gaan Mahu Machhi  Pranab Kishore Patnaik
# 38816  Tuma Gaan Mahu Machhi  Pranab Kishore Patnaik
# 38837  Tuma Gaan Mahu Machhi  Pranab Kishore Patnaik
#
#                             singer_id duration                        link  \
# 38476  /artist/pranab-kishore-patnaik    02:56            /a-gori-chal-ame
# 38631  /artist/pranab-kishore-patnaik    02:58                /nijhum-rati
# ...

# %% [markdown]
# 2.2) "singer" Column Exploration and Cleaning 🔍🧹

# %%
df['singer']
# Out:
# 0             Chitra Singh|Jagjit Singh
# 1             Chitra Singh|Jagjit Singh
# 2                          Jagjit Singh
# 3                          Chitra Singh
# 4                          Jagjit Singh
#                       ...
# 41350                     Kishore Kumar
# 41351                      Feroza Begum
# 41352    Sandhya Mukherjee|Hemant Kumar
# 41353                  Ajoy Chakrabarty
# 41354                       Asha Bhosle
# Name: singer, Length: 41355, dtype: object

# %%
df["singer"].nunique()
# Out:
# 6196

# %%
df["singer"].value_counts()
# Out:
# singer
# Lata Mangeshkar                                                                                                                                                                                   1410
# Asha Bhosle                                                                                                                                                                                       1274
# Kishore Kumar                                                                                                                                                                                     1213
# Mohammed Rafi                                                                                                                                                                                     1201
# ...

# %% [markdown]
# 2.3) "singer_id" Column Exploration and Cleaning 🔍🧹

# %%
df['singer_id']
# Out:
# 0             /artist/chitra-singh|/artist/jagjeet-singh-1
# 1             /artist/chitra-singh|/artist/jagjeet-singh-1
# 2                                  /artist/jagjeet-singh-1
# 3                                     /artist/chitra-singh
# 4                                  /artist/jagjeet-singh-1
#                                ...
# 41350                                /artist/kishore-kumar
# 41351                                 /artist/feroza-begum
# 41352    /artist/sandhya-mukherjee|/artist/hemanta-mukh...
# 41353                             /artist/ajoy-chakrabarty
# 41354                                /artist/asha-bhosle-1
# Name: singer_id, Length: 41355, dtype: object

# %%
df['singer_id'].nunique()
# Out:
# 6580

# %%
df['singer_id'].value_counts()
# Out:
# singer_id
# /artist/lata-mangeshkar                                                1410
# /artist/asha-bhosle-1                                                  1274
# /artist/kishore-kumar                                                  1213
# /artist/mohammad-rafi                                                  1201
# /artist/s-p-balasubrahamanyam                                          1168
#                                                                        ...
# /artist/tm-soundararajan|/artist/al-raghavan-1|/artist/p-suseela-2        1
# /artist/tm-soundararajan|/artist/lr-anjali                                1
# /artist/uma-ramanan-1|/artist/raadhika-sarathkumar-6|/artist/chorus       1
# /artist/mallika-duraipandian|/artist/chorus                               1
# /artist/latha|/artist/chorus                                              1
# Name: count, Length: 6580, dtype: int64

# %% [markdown]
# 2.4) "duration" Column Exploration and Cleaning 🔍🧹

# %%
df['duration'].nunique()
# Out:
# 1309

# %%
h = 0
m = 0
s = 0
for i in df['duration']:
  if len(i.split(':')) == 3:
    h+=1
  elif len(i.split(':')) == 2:
    m+=1
  else:
    s+=1
print(h,m,s)
# Out:
# 71 41284 0

# %%
lst = []
for i in df['duration']:
  if len(i.split(':')) == 3:
    hour = int(i.split(':')[0])
    mins = int(i.split(':')[1])
    secs = int(i.split(':')[2])
    duration = hour*3600+mins*60+secs
    lst.append(duration)

  elif len(i.split(':')) == 2:
    mins = int(i.split(':')[0])
    secs = int(i.split(':')[1])
    duration = mins*60 + secs
    lst.append(duration)

# %%
df['duration_in_sec'] = lst

# %%
df.head()
# Out:
#                                       name                     singer  \
# 0                    Dil - E - Nadan Tujhe  Chitra Singh|Jagjit Singh
# 1        Agar Hum Kahen Aur Woh Muskara De  Chitra Singh|Jagjit Singh
# 2                            Unke Dekhe Se               Jagjit Singh
# 3  Yeh Na Thi Hamari Qismat - Chitra Singh               Chitra Singh
# 4                  Hazaron Khwahishen Aisi               Jagjit Singh
#
#                                       singer_id duration  \
# 0  /artist/chitra-singh|/artist/jagjeet-singh-1    05:00
# 1  /artist/chitra-singh|/artist/jagjeet-singh-1    06:26
# 2                       /artist/jagjeet-singh-1    03:41
# 3                          /artist/chitra-singh    04:26
# 4                       /artist/jagjeet-singh-1    05:39
#
#                                   link language  duration_in_sec
# 0                 /dil-e-nadan-tujhe-3     Urdu              300
# 1  /agar-hum-kahen-aur-woh-muskura-den     Urdu              386
# ...

# %%
del df['duration']

# %%
df['duration_in_sec'].sort_values(ascending = False)
# Out:
# 16093    25680
# 15000    24720
# 16352    24720
# 15025    21840
# 14624    21780
#          ...
# 6500        18
# 36778       18
# 35561       17
# 22952       17
# 27945       17
# Name: duration_in_sec, Length: 41355, dtype: int64

# %%
df.sort_values('duration_in_sec',ascending= False).head(10)
# Out:
#                                name          singer               singer_id  \
# 16093                    Haye Tumba  Dilshad Akhtar  /artist/dilshad-akhtar
# 15000                Bum Bum Lahiri  Dilshad Akhtar  /artist/dilshad-akhtar
# 16352                Bum Bum Lahiri  Dilshad Akhtar  /artist/dilshad-akhtar
# 15025          Kanu Atharu Bahoundi  Dilshad Akhtar  /artist/dilshad-akhtar
# 14624  Desi Bandri Vilayati Cheekan  Dilshad Akhtar  /artist/dilshad-akhtar
# 16022  Desi Bandri Vilayati Cheekan  Dilshad Akhtar  /artist/dilshad-akhtar
# 15259        Kunda Khol Basantariye  Dilshad Akhtar  /artist/dilshad-akhtar
# 16027                 Ghund Kad Lai  Dilshad Akhtar  /artist/dilshad-akhtar
# 14655                 Ghund Kad Lai  Dilshad Akhtar  /artist/dilshad-akhtar
# 15402               Man Wich Vasnai  Dilshad Akhtar  /artist/dilshad-akhtar
#
#                                   link language  duration_in_sec
# 16093                      /haye-tumba  Punjabi            25680
# ...

# %% [markdown]
# 2.5) "link" Column Exploration and Cleaning 🔍🧹

# %%
df['link']
# Out:
# 0                                     /dil-e-nadan-tujhe-3
# 1                      /agar-hum-kahen-aur-woh-muskura-den
# 2                                           /unke-dekhe-se
# 3                              /yeh-na-thi-hamari-qismat-2
# 4                               /hazaron-khwahishen-aisi-1
#                                ...
# 41350    /chaaridike-paaper-andhar-manush-janam-diye-bidhi
# 41351                                   /ei-kigo-sesh-daan
# 41352                                        /ei-je-bangla
# 41353                                /jatone-hridaye-rekho
# 41354                             /tomar-je-oi-haater-mala
# Name: link, Length: 41355, dtype: object

# %%
df['link'].nunique()
# Out:
# 36361

# %%
df['link'].value_counts()
# Out:
# link
# /ek-baar-zara-phir-keh-do         2
# /girdhari-chhed-muraliya-pyari    2
# /jab-se-tumhen-dekha-hai          2
# /dil-ka-bhanwar-kare-pukar-7      2
# /goom-hai-kisi-ke-pyar-mein-2     2
#                                  ..
# /bahujanamadaa                    1
# /ahorathri-niladodi               1
# /bitthe-nendede                   1
# /chinna-baalalli-1                1
# /ondondagi-jaridare               1
# Name: count, Length: 36361, dtype: int64

# %% [markdown]
# 2.6) "language" Column Exploration and Cleaning 🔍🧹

# %%
df['language']
# Out:
# 0           Urdu
# 1           Urdu
# 2           Urdu
# 3           Urdu
# 4           Urdu
#           ...
# 41350    Bengali
# 41351    Bengali
# 41352    Bengali
# 41353    Bengali
# 41354    Bengali
# Name: language, Length: 41355, dtype: object

# %%
df['language'].unique()
# Out:
# array(['Urdu', 'Gujarati', 'Tamil', 'Kannada', 'Rajasthani', 'Haryanvi',
#        'Punjabi', 'Hindi', 'Old', 'Malayalam', 'Marathi', 'Telugu',
#        'Odia', 'Bhojpuri', 'Assamese', 'Bengali'], dtype=object)

# %%
df['language'].nunique()
# Out:
# 16

# %%
df['language'].value_counts()
# Out:
# language
# Telugu        4996
# Hindi         4993
# Old           4993
# Marathi       4699
# Tamil         4677
# Punjabi       3818
# Kannada       3559
# Urdu          3116
# Gujarati      2115
# Bengali        958
# Odia           940
# Assamese       724
# Rajasthani     541
# Bhojpuri       519
# Malayalam      479
# Haryanvi       228
# Name: count, dtype: int64

# %%
df['language'].value_counts().sort_values(ascending= False)
# Out:
# language
# Telugu        4996
# Hindi         4993
# Old           4993
# Marathi       4699
# Tamil         4677
# Punjabi       3818
# Kannada       3559
# Urdu          3116
# Gujarati      2115
# Bengali        958
# Odia           940
# Assamese       724
# Rajasthani     541
# Bhojpuri       519
# Malayalam      479
# Haryanvi       228
# Name: count, dtype: int64

# %%
df['language'].value_counts().sort_values(ascending= False).plot(kind = 'bar', title = "Count of songs in each language", figsize = (12,6))
# Out:
# <Axes: title={'center': 'Count of songs in each language'}, xlabel='language'>

# %% [markdown]
# 3) Data Analysis **📈**

# %% [markdown]
# KPI'**s**

# %% [markdown]
# 1. Most Popular Song
#
# 2. Most Popular Singer
#
# 3. Cumulative Song Duration (12 Days 13 HOurs 24 min 12 sec)
#
# 4. Total No of Languages
#
# 5. Total No of Songs
#
# 6. Total No of Singers
#
# 7. Min and Max Duration

# %% [markdown]
# 3.1) Most Popular Song

# %%
df.groupby('name').size().sort_values(ascending= False).head(5)
# Out:
# name
# O Mere Dil Ke Chain               26
# Hamen Tumse Pyar Kitna            22
# Padhyams                          20
# Yeh Sham Mastani                  18
# Chura Liya Hai Tumne Jo Dil Ko    18
# dtype: int64

# %%
df.groupby('name').size().sort_values(ascending= False).head(5).plot(kind = 'pie', title = 'Most Popular Song', autopct = '%.2f' )
# Out:
# <Axes: title={'center': 'Most Popular Song'}>

# %% [markdown]
# 3.2) Most Popular Singer

# %%
lst = []
for i in df['singer']:
  lst = lst + (i.split("|"))


pd.Series(lst).value_counts().head(10)
# Out:
# S. P. Balasubrahmanyam    3659
# P. Susheela               3212
# Lata Mangeshkar           3056
# Asha Bhosle               2715
# Kishore Kumar             2401
# S. Janaki                 2204
# Mohammed Rafi             2133
# Chorus                    1149
# Ghanatasala               1110
# P.B. Sreenivas             937
# Name: count, dtype: int64

# %%
pd.Series(lst).value_counts().head(10).plot(kind = 'bar', figsize = (12,12), title = 'Most Popular Singer')
# Out:
# <Axes: title={'center': 'Most Popular Singer'}>

# %% [markdown]
# 3.3) Cumulative Song Duration (12 Days 13 Hours 24 min 12 sec)

# %%
df['duration_in_sec'].sum()
# Out:
# np.int64(12925899)

# %%
def second_conversion():
  sec = int(input("enter secs: "))
  day = sec//86400
  hour = (sec % 86400) // 3600
  mins = ((sec % 86400) % 3600) //60
  secs =  ((sec % 86400) % 3600) % 60
  return f"{day} days {hour} hours {mins} mins {secs} secs "

# %%
print(second_conversion())
# Out:
# enter secs: 10316275
# 119 days 9 hours 37 mins 55 secs

# %% [markdown]
# 3.4) Total No of Languages

# %%
df['language'].nunique()
# Out:
# 16

# %%
df['language'].value_counts().sort_values(ascending= False)
# Out:
# language
# Telugu        4996
# Hindi         4993
# Old           4993
# Marathi       4699
# Tamil         4677
# Punjabi       3818
# Kannada       3559
# Urdu          3116
# Gujarati      2115
# Bengali        958
# Odia           940
# Assamese       724
# Rajasthani     541
# Bhojpuri       519
# Malayalam      479
# Haryanvi       228
# Name: count, dtype: int64

# %%
df['language'].value_counts().sort_values(ascending= False).plot(kind = 'bar', figsize = (12,12), title = 'Count of Songs according to language')
# Out:
# <Axes: title={'center': 'Count of Songs according to language'}, xlabel='language'>

# %%
plt.figure(figsize = (12,12))
sns.countplot(x = 'language', data = df )
# Out:
# <Axes: xlabel='language', ylabel='count'>

# %% [markdown]
# 3.5) Total No of Songs

# %%
c= df['name'].count()
print(f"Total number of songs are {c}")
# Out:
# Total number of songs are 41355

# %% [markdown]
# 3.6) Total No of Singers

# %%
lst = []
for i in df['singer']:
  lst = lst + (i.split("|"))

# %%
c= pd.Series(lst).nunique()
print(f"Total no of singers are {c}.")
# Out:
# Total no of singers are 3940.

# %% [markdown]
# 3.7) Min Duration

# %%
df[['name','duration_in_sec']].sort_values(by = 'duration_in_sec',ascending = True).head(5)
# Out:
#                                             name  duration_in_sec
# 22952  Dialogues (Ghulami): Aahi Jaana Mere Liye               17
# 27945  Dialogues (Ghulami): Aahi Jaana Mere Liye               17
# 35561       Title Musics - Jagadekaveeruni Katha               17
# 36778  Introduction Telegu Films Idi Mallelavela               18
# 6500                                   Dialogues               18

# %% [markdown]
# 3.8) Max Duration

# %%
df[['name','duration_in_sec']].sort_values(by = 'duration_in_sec', ascending = False).head(5)
# Out:
#                                name  duration_in_sec
# 16093                    Haye Tumba            25680
# 15000                Bum Bum Lahiri            24720
# 16352                Bum Bum Lahiri            24720
# 15025          Kanu Atharu Bahoundi            21840
# 14624  Desi Bandri Vilayati Cheekan            21780
